# %% [markdown]
# ### Plotting the data from Dexcom
#
# * Open the Dexcom clarity website
# * Change the duration to 90 days
# * Open the developers tools panel and go to "Network"
# * Select the "data" XHR call, and right click "Copy > Copy as CURL (bash)"
# * Take the CURL command and paste it to https://curl.trillworks.com/ to get the Python requests code

# %%
# This is the CURL command (it works)
# !curl 'https://clarity.dexcom.com/api/subject/1522320180078616576/analysis_session/1560634749054713856/data' -H 'Origin: https://clarity.dexcom.com' -H 'Accept-Encoding: gzip, deflate, br' -H 'X-CSRF-Token: GsNf00qQfUCsnSKYqPmBHpUIDohT82bZdLMNZkT08I4=' -H 'Accept-Language: en-US,en;q=0.8,el;q=0.6' -H 'Access-Token: eyJhbGciOiJSUzI1NiJ9..ugrEvUViRZiIsWRh_WpPsGeBxffReG0OhC6NrmZZmjnXwbi4DD3EEhv8YTzTaFQk7qkhGwMJxd-OEDi8cvI3mE2v0D8Kh4UnDgAe5d6bsmxbRAGIyG_rGIc08rHKE01te3ZzYLLHXUKejtpCiIY4sB1Au1Vi4FBZq06Dsm6meJviz14SYTWYJ_oAfhyQTF5mjIpXlY-EV30cQ8flGW_wFGgQSwoBLfT3RSf0yY4gY1dh6M9nktw_no3b4RbqHFm2Z-p5_xez8PcJUHyuZcaYDNkuUWhkcSC5BwWTDKc-fPJBJ3NYrKLO9DW-IkB4kA-pHIOPl06AadNtfAwsS296ag' -H 'Cookie: __qca=P0-1747429584-1485356873509; optimizelyEndUserId=oeu1485356872961r0.08355624940963469; _vwo_uuid_v2=B119E3AABEF84DD116E5E25C6C7BBDDE|033a88ef553ff6e80ad851dc51125699; _ga=GA1.2.1227389678.1485356873; _rogue_session=...%3D%3D--08eed795a7f1d792a4f2a8e54708534ee89f9a0d' -H 'Connection: keep-alive' -H 'X-NewRelic-ID: UwMPUlZVGwIAV1ZQAwUE' -H 'X-Requested-With: XMLHttpRequest' -H 'User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36' -H 'Content-Type: application/json' -H 'Accept: application/json, text/javascript, */*; q=0.01' -H 'Referer: https://clarity.dexcom.com/' -H 'DNT: 1' --data-binary '{"localDateTimeInterval":["2016-12-01/2017-03-01"]}' --compressed
# Out:
# {
#   "glucoseTargetRanges": [{
#     "name": "day",
#     "startTime": "08:30:00",
#     "endTime": "23:45:00",
#     "glucoseRange": {
#       "min": 70,
#       "max": 140
#     }
#   }, {
#     "name": "night",
#     "startTime": "23:45:00",
#     "endTime": "08:30:00",
#     "glucoseRange": {
#       "min": 60,
#       "max": 130
#     }
#   }],
#   "unitGroups": [{
#     "unit": {
#       "family": "glucose",
#       "id": 2,
#       "name": "cgm"
#     },
#     "lowExceeded": [],
#     "highExceeded": [],
#     "timeMagnitudes": [{
#       "time": "2017-02-01T22:49:57",
#       "magnitude": 126.0,
#       "transmitterTime": 12606,
#       "absoluteTime": "2017-02-02T03:49:57"
#     }, {
#       "time": "2017-02-01T22:54:51",
#       "magnitude": 135.0,
#       "transmitterTime": 12900,
#       "absoluteTime": "2017-02-02T03:54:51"
#     }, {
#       "time": "2017-02-01T22:59:51",
#       "magnitude": 135.0,
#       "transmitterTime": 13200,
# ...

# %%
# And below we have the Python requests code

# %%
import requests

cookies = {
    '__qca': 'P0-1747429584-1485356873509',
    'optimizelyEndUserId': 'oeu1485356872961r0.08355624940963469',
    '_vwo_uuid_v2': 'B119E3AABEF84DD116E5E25C6C7BBDDE|033a88ef553ff6e80ad851dc51125699',
    '_ga': 'GA1.2.1227389678.1485356873',
    '_rogue_session': '...--346324938f37a753a709122d8562726143794c53',
}

headers = {
    'Origin': 'https://clarity.dexcom.com',
    'Accept-Encoding': 'gzip, deflate, br',
    'X-CSRF-Token': 'wplKQN/CocECFf3jNlAE6UQT1peiqmUuNwHF4QTFkeg=',
    'Accept-Language': 'en-US,en;q=0.8,el;q=0.6',
    'Access-Token': 'eyJhbGciOiJSUzI1NiJ9..QK44VTYjW7x159BKRpg508AJr2DQriNFFjH9_NFKEuBO2cp8oGtZTBPhgeEDWgDJ5EYKueIZte6_S57jembZMyJF6mjajO9ZEmbTyoyo-IcNOCM0bkazaLWJ75tdoiFjf1-XQDau2UzqpUpHWdoyyKaUhseq5N9id967uZ5hOE5tJeDhCaRq5Q7kmM5c8XU3TC24f7BJyrHcpubJVPTaQ54Xg6UzGnUepOLktMhJwbD0gOlRDNH_-QfBQGv_fJjI2oq-OpCjDv2tI23V43mUqDeYqdauyA0jUGtKNfq-Bqe3Jr72Q6r47EuZ07Ar5kPBrjrqXLiMO8fryCGVwSyhww',
    'Connection': 'keep-alive',
    'X-NewRelic-ID': 'UwMPUlZVGwIAV1ZQAwUE',
    'X-Requested-With': 'XMLHttpRequest',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
    'Content-Type': 'application/json',
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'Referer': 'https://clarity.dexcom.com/',
    'DNT': '1',
}

data = '{"localDateTimeInterval":["2017-02-01/2017-03-03"]}'

resp = requests.post('https://clarity.dexcom.com/api/subject/1522320180078616576/analysis_session/1560770594111492096/data', headers=headers, cookies=cookies, data=data)

results = resp.json()

# %%
results.keys()
# Out:
# dict_keys(['unitGroups', 'glucoseTargetRanges', 'events'])

# %%
len(results['unitGroups'])
# Out:
# 1

# %%
import pandas as pd
df = pd.DataFrame(results['unitGroups'][0]['timeMagnitudes'])

# %%
df.head()
# Out:
#           absoluteTime  magnitude                 time  transmitterTime
# 0  2017-02-02T03:49:57      126.0  2017-02-01T22:49:57            12606
# 1  2017-02-02T03:54:51      135.0  2017-02-01T22:54:51            12900
# 2  2017-02-02T03:59:51      135.0  2017-02-01T22:59:51            13200
# 3  2017-02-02T04:04:51      131.0  2017-02-01T23:04:51            13500
# 4  2017-02-02T04:09:51      132.0  2017-02-01T23:09:51            13800

# %%
df['localTime'] = pd.to_datetime(df['time'])
df.set_index('localTime', inplace=True)
df.drop(['absoluteTime','time','transmitterTime'],inplace=True, axis=1)

# %%
df.dtypes
# Out:
# magnitude    float64
# dtype: object

# %%
# %matplotlib inline
df.plot(figsize=(20,10), grid=True)

# %%
df_a1c = pd.DataFrame(df['magnitude'].resample('D').mean())
df_a1c['eBG'] = df_a1c['magnitude'].ewm(span=90).mean()
df_a1c['a1c'] =  (df_a1c['magnitude'] + 46.7)/28.7 + 0.5

# %%
# The +0.5 factor is my own personal adjustment, based on past A1C measurements

df_a1c
# Out:
#              magnitude         eBG       a1c
# localTime
# 2017-02-01  131.333333  131.333333  6.703252
# 2017-02-02  112.411765  121.767429  6.043964
# 2017-02-03  110.110345  117.795069  5.963775
# 2017-02-04   96.965753  112.412891  5.505775
# 2017-02-05   98.043796  109.409944  5.543338
# 2017-02-06   95.641577  106.985864  5.459637
# 2017-02-07  130.658621  110.597268  6.679743
# 2017-02-08  105.617424  109.925309  5.807227
# 2017-02-09  108.503448  109.752922  5.907786
# 2017-02-10  101.424710  108.834381  5.661140
# 2017-02-11  109.372822  108.888948  5.938077
# 2017-02-12  107.344828  108.743969  5.867416
# 2017-02-13  103.424138  108.277994  5.730806
# 2017-02-14  104.228374  107.945121  5.758828
# 2017-02-15   95.362069  106.969560  5.449898
# 2017-02-16   94.777778  106.074079  5.429539
# 2017-02-17   97.820833  105.497557  5.535569
# 2017-02-18   98.096552  105.004187  5.545176
# 2017-02-19   90.923875  104.105707  5.295257
# 2017-02-20   93.913793  103.481463  5.399435
# ...

# %%
df_a1c.plot(figsize=(20,10), grid=True)

# %%
df_a1c['a1c'].plot(figsize=(20,10), grid=True)

# %%
January 6th: 5.6
June 1st: 5.5
    May 10th: 5.7
