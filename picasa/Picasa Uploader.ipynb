# %%
import sys


import argparse
import atom
import atom.service
import filecmp
import gdata
import gdata.photos.service
import gdata.media
import gdata.geo
import gdata.gauth
import getpass
import httplib2
import os
import subprocess
import tempfile
import time
import webbrowser

from datetime import datetime, timedelta
from oauth2client.client import flow_from_clientsecrets
from oauth2client.file import Storage
from gdata.photos.service import GPHOTOS_INVALID_ARGUMENT, GPHOTOS_INVALID_CONTENT_TYPE, GooglePhotosException


import gdata.photos.service
import gdata.media
import gdata.geo

import os

import oauth2client

import httplib2

from oauth2client.client import flow_from_clientsecrets
from oauth2client.file import Storage

import threading

import datetime

# This part is required to come up with the pop-up with which Jawbone will ask for permissions
from IPython.display import display
from IPython.display import Javascript as JS

import requests
import os


PICASA_MAX_VIDEO_SIZE_BYTES = 104857600

class VideoEntry(gdata.photos.PhotoEntry):
    pass

gdata.photos.VideoEntry = VideoEntry

def InsertVideo(self, album_or_uri, video, filename_or_handle, content_type='image/jpeg'):
    """Copy of InsertPhoto which removes protections since it *should* work"""
    try:
        assert(isinstance(video, VideoEntry))
    except AssertionError:
        raise GooglePhotosException({'status':GPHOTOS_INVALID_ARGUMENT,
            'body':'`video` must be a gdata.photos.VideoEntry instance',
            'reason':'Found %s, not PhotoEntry' % type(video)
        })
    try:
        majtype, mintype = content_type.split('/')
        #assert(mintype in SUPPORTED_UPLOAD_TYPES)
    except (ValueError, AssertionError):
        raise GooglePhotosException({'status':GPHOTOS_INVALID_CONTENT_TYPE,
            'body':'This is not a valid content type: %s' % content_type,
            'reason':'Accepted content types:'
        })
    if isinstance(filename_or_handle, (str, unicode)) and \
        os.path.exists(filename_or_handle): # it's a file name
        mediasource = gdata.MediaSource()
        mediasource.setFile(filename_or_handle, content_type)
    elif hasattr(filename_or_handle, 'read'):# it's a file-like resource
        if hasattr(filename_or_handle, 'seek'):
            filename_or_handle.seek(0) # rewind pointer to the start of the file
        # gdata.MediaSource needs the content length, so read the whole image
        file_handle = StringIO.StringIO(filename_or_handle.read())
        name = 'image'
        if hasattr(filename_or_handle, 'name'):
            name = filename_or_handle.name
        mediasource = gdata.MediaSource(file_handle, content_type,
            content_length=file_handle.len, file_name=name)
    else: #filename_or_handle is not valid
        raise GooglePhotosException({'status':GPHOTOS_INVALID_ARGUMENT,
            'body':'`filename_or_handle` must be a path name or a file-like object',
            'reason':'Found %s, not path name or object with a .read() method' % \
            type(filename_or_handle)
        })

    if isinstance(album_or_uri, (str, unicode)): # it's a uri
        feed_uri = album_or_uri
    elif hasattr(album_or_uri, 'GetFeedLink'): # it's a AlbumFeed object
        feed_uri = album_or_uri.GetFeedLink().href

    try:
        return self.Post(video, uri=feed_uri, media_source=mediasource,
            converter=None)
    except gdata.service.RequestError as e:
        raise GooglePhotosException(e.args[0])

gdata.photos.service.PhotosService.InsertVideo = InsertVideo

def OAuth2Login(client_secrets, credential_store, email):
    scope='https://picasaweb.google.com/data/'
    user_agent='PicasaMigrator'

    storage = Storage(credential_store)
    credentials = storage.get()
    if credentials is None or credentials.invalid:
        flow = flow_from_clientsecrets(client_secrets, scope=scope, redirect_uri='urn:ietf:wg:oauth:2.0:oob')
        uri = flow.step1_get_authorize_url()
        
        threading.Timer(1, lambda: display(JS("window.open('%s')" % uri))).start()

        code = raw_input('Enter the authentication code: ').strip()
        credentials = flow.step2_exchange(code)
        storage.put(credentials)

    if (credentials.token_expiry - datetime.datetime.utcnow()) < datetime.timedelta(minutes=5):
        http = httplib2.Http()
        http = credentials.authorize(http)
        credentials.refresh(http)

    gd_client = gdata.photos.service.PhotosService(source=user_agent,
                                               email=email,
                                               additional_headers={'Authorization' : 'Bearer %s' % credentials.access_token})

    return gd_client

def protectWebAlbums(gd_client):
    albums = gd_client.GetUserFeed()
    for album in albums.entry:
        #print('title: %s, number of photos: %s, id: %s summary: %s access: %s\n' % (album.title.text,
        # album.numphotos.text, album.gphoto_id.text, album.summary.text, album.access.text))
        needUpdate = False
        if album.access.text != 'protected' and album.title.text not in ['Auto Backup', 'Profile Photos', 'Scrapbook Photos']:
            album.access.text = 'protected'
            needUpdate = True
        # print album
        if needUpdate:
            print("updating " + album.title.text)
            try:
                updated_album = gd_client.Put(album, album.GetEditLink().href,
                        converter=gdata.photos.AlbumEntryFromString)
            except gdata.service.RequestError as e:
                print("Could not update album: " + str(e))

def getWebAlbums(gd_client):
    albums = gd_client.GetUserFeed()
    d = {}
    for album in albums.entry:
        title = album.title.text
        if title in d:
          print("Duplicate web album:" + title)
        else:
          d[title] = album
        # print('title: %s, number of photos: %s, id: %s' % (album.title.text,
        #    album.numphotos.text, album.gphoto_id.text))
        #print(vars(album))
    return d

def findAlbum(gd_client, title):
    albums = gd_client.GetUserFeed()
    for album in albums.entry:
        if album.title.text == title:
            return album
    return None

def createAlbum(gd_client, title):
    print("Creating album " + title)
    # public, private, protected. private == "anyone with link"
    album = gd_client.InsertAlbum(title=title, summary='', access='protected')
    return album

def findOrCreateAlbum(gd_client, title):
    delay = 1
    while True:
        try:
            album = findAlbum(gd_client, title)
            if not album:
                album = createAlbum(gd_client, title)
            return album
        except gdata.photos.service.GooglePhotosException as e:
            print("caught exception " + str(e))
            print("sleeping for " + str(delay) + " seconds")
            time.sleep(delay)
            delay = delay * 2

def postPhoto(gd_client, album, filename):
    album_url = '/data/feed/api/user/%s/albumid/%s' % (gd_client.email, album.gphoto_id.text)
    photo = gd_client.InsertPhotoSimple(album_url, 'New Photo',
            'Uploaded using the API', filename, content_type='image/jpeg')
    return photo

def postPhotoToAlbum(gd_client, photo, album):
    album = findOrCreateAlbum(gd_client, args.album)
    photo = postPhoto(gd_client, album, args.source)
    return photo

def getWebPhotosForAlbum(gd_client, album):
    photos = gd_client.GetFeed(
            '/data/feed/api/user/%s/albumid/%s?kind=photo' % (
            gd_client.email, album.gphoto_id.text))
    return photos.entry

allExtensions = {}

# key: extension, value: type
knownExtensions = {
    '.png': 'image/png',
    '.jpeg': 'image/jpeg',
    '.jpg': 'image/jpeg',
    '.avi': 'video/avi',
    '.wmv': 'video/wmv',
    '.3gp': 'video/3gp',
    '.m4v': 'video/m4v',
    '.mp4': 'video/mp4',
    '.mov': 'video/mov'
    }

def getContentType(filename):
    ext = os.path.splitext(filename)[1].lower()
    if ext in knownExtensions:
        return knownExtensions[ext]
    else:
        return None

def accumulateSeenExtensions(filename):
    ext = os.path.splitext(filename)[1].lower()
    if ext in allExtensions:
        allExtensions[ext] = allExtensions[ext] + 1
    else:
        allExtensions[ext] = 1

def isMediaFilename(filename):
    accumulateSeenExtensions(filename)
    return getContentType(filename) != None

def visit(arg, dirname, names):
    basedirname = os.path.basename(dirname)
    if basedirname.startswith('.'):
        return
    mediaFiles = [name for name in names if not name.startswith('.') and isMediaFilename(name) and
        os.path.isfile(os.path.join(dirname, name))]
    count = len(mediaFiles)
    if count > 0:
        arg[dirname] = {'files': sorted(mediaFiles)}

def findMedia(source):
    hash = {}
    os.path.walk(source, visit, hash)
    return hash

def findDupDirs(photos):
    d = {}
    for i in photos:
        base = os.path.basename(i)
        if base in d:
            print("duplicate " + base + ":\n" + i + ":\n" + d[base])
            dc = filecmp.dircmp(i, d[base])
            print(dc.diff_files)
        d[base] = i
    # print([len(photos[i]['files']) for i in photos])

def toBaseName(photos):
    d = {}
    for i in photos:
        base = os.path.basename(i)
        if base in d:
            print("duplicate " + base + ":\n" + i + ":\n" + d[base]['path'])
            raise Exception("duplicate base")
        p = photos[i]
        p['path'] = i
        d[base] = p
    return d

def compareLocalToWeb(local, web):
    localOnly = []
    both = []
    webOnly = []
    for i in local:
        if i in web:
            both.append(i)
        else:
            localOnly.append(i)
    for i in web:
        if i not in local:
            webOnly.append(i)
    return {'localOnly' : localOnly, 'both' : both, 'webOnly' : webOnly}

def compareLocalToWebDir(localAlbum, webPhotoDict):
    localOnly = []
    both = []
    webOnly = []
    for i in localAlbum:
        if i in webPhotoDict:
            both.append(i)
        else:
            localOnly.append(i)
    for i in webPhotoDict:
        if i not in localAlbum:
            webOnly.append(i)
    return {'localOnly' : localOnly, 'both' : both, 'webOnly' : webOnly}

def syncDirs(gd_client, dirs, local, web):
    for dir in dirs:
        syncDir(gd_client, dir, local[dir], web[dir])

def syncDir(gd_client, dir, localAlbum, webAlbum):
    webPhotos = getWebPhotosForAlbum(gd_client, webAlbum)
    webPhotoDict = {}
    for photo in webPhotos:
        title = photo.title.text
        if title in webPhotoDict:
            print("duplicate web photo: " + webAlbum.title.text + " " + title)
        else:
            webPhotoDict[title] = photo
    report = compareLocalToWebDir(localAlbum['files'], webPhotoDict)
    localOnly = report['localOnly']
    for f in localOnly:
        localPath = os.path.join(localAlbum['path'], f)
        upload(gd_client, localPath, webAlbum, f)

def uploadDirs(gd_client, dirs, local):
    for dir in dirs:
        uploadDir(gd_client, dir, local[dir])

def uploadDir(gd_client, dir, localAlbum):
    webAlbum = findOrCreateAlbum(gd_client, dir)
    for f in localAlbum['files']:
        localPath = os.path.join(localAlbum['path'], f)
        upload(gd_client, localPath, webAlbum, f)

# Global used for a temp directory
gTempDir = ''

def getTempPath(localPath):
    baseName = os.path.basename(localPath)
    global gTempDir
    if gTempDir == '':
        gTempDir = tempfile.mkdtemp('imageshrinker')
    tempPath = os.path.join(gTempDir, baseName)
    return tempPath

def upload(gd_client, localPath, album, fileName):
    print("Uploading " + localPath)
    contentType = getContentType(fileName)

    if contentType.startswith('image/'):
        isImage = True
        picasa_photo = gdata.photos.PhotoEntry()
    else:
        size = os.path.getsize(localPath)

        # tested by cpbotha on 2013-05-24
        # this limit still exists
        if size > PICASA_MAX_VIDEO_SIZE_BYTES:
            print("Video file too big to upload: " + str(size) + " > " + str(PICASA_MAX_VIDEO_SIZE_BYTES))
            return
        isImage = False
        picasa_photo = VideoEntry()
    picasa_photo.title = atom.Title(text=fileName)
    picasa_photo.summary = atom.Summary(text='', summary_type='text')
    delay = 1
    while True:
        try:
            if isImage:
                gd_client.InsertPhoto(album, picasa_photo, localPath, content_type=contentType)
            else:
                gd_client.InsertVideo(album, picasa_photo, localPath, content_type=contentType)
            break
        except gdata.photos.service.GooglePhotosException as e:
          print("Got exception " + str(e))
          print("retrying in " + str(delay) + " seconds")
          time.sleep(delay)
          delay = delay * 2

# options for oauth2 login
email = 'ipeirotis@gmail.com'
configdir = os.path.expanduser('/scratch/picasa')
client_secrets = os.path.join(configdir, 'client_secret_ipeirotis.json')
credential_store = os.path.join(configdir, 'credentials_ipeirotis.dat')
gd_client = OAuth2Login(client_secrets, credential_store, email)
source = '/scratch/picasa'

#protectWebAlbums(gd_client)
webAlbums = getWebAlbums(gd_client)
localAlbums = toBaseName(findMedia(source))
albumDiff = compareLocalToWeb(localAlbums, webAlbums)
syncDirs(gd_client, albumDiff['both'], localAlbums, webAlbums)
uploadDirs(gd_client, albumDiff['localOnly'], localAlbums)

# %%
# Out:
# Duplicate web album:6/4/14
# Duplicate web album:2014-06-03
# Duplicate web album:2014-05-21
# Duplicate web album:2014-05-21
# Duplicate web album:2014-04-24
# Duplicate web album:2014-04-24
# Duplicate web album:2014-04-24
# Duplicate web album:2014-04-24
# Duplicate web album:2014-04-24
# Duplicate web album:2014-04-24
# Duplicate web album:9/3/13
# Duplicate web album:8/24/13
# Duplicate web album:8/24/13
# Duplicate web album:7/15/13
# Duplicate web album:2013-06-17
# Duplicate web album:2013-06-17
# Duplicate web album:5/6/13
# Duplicate web album:2013-07-14
# Duplicate web album:Panoramas
# Creating album Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/1.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/10.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/11.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/12.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/13.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/14.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/15.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/16.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/17.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/18.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/19.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/2.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/20.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/21.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/22.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/23.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/24.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/25.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/26.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/27.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/28.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/29.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/3.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/30.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/31.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/32.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/33.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/34.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/35.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/36.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/37.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/38.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/39.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/4.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/40.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/41.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/42.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/43.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/44.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/45.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/46.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/47.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/48.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/49.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/5.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/50.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/51.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/52.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/53.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/54.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/55.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/56.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/57.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/58.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/59.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/6.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/60.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/61.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/62.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/63.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/64.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/65.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/66.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/67.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/68.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/69.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/7.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/70.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/71.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/72.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/73.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/74.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/75.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/76.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/77.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/78.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/79.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/8.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/80.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/81.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/82.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/83.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/85.jpeg
# Uploading /scratch/picasa/Month 5, Πέμπτος μήνας, Пятый месяц 5709215817013039313/9.jpeg
# Creating album Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/1.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/10.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/11.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/12.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/13.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/14.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/15.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/16.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/17.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/18.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/19.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/2.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/20.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/21.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/22.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/23.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/24.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/25.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/26.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/27.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/28.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/29.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/3.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/30.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/31.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/4.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/5.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/6.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/7.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/8.jpeg
# Uploading /scratch/picasa/Day 5, Πέμπτη μέρα, Пятый день 5615685824744838817/9.jpeg
# Creating album Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/1.jpeg
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/10.jpeg
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/11.jpeg
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/12.jpeg
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/13.jpeg
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/14.jpeg
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/15.jpeg
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/16.jpeg
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/17.jpeg
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/18.jpeg
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/2.jpeg
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/3.jpeg
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/4.jpeg
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/5.jpeg
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/6.jpeg
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/7.jpeg
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/8.jpeg
# Uploading /scratch/picasa/Day 8, Όγδοη μέρα, Восьмой день 5616989458479301697/9.jpeg
# Creating album July 2013 5968222817558851361
# Uploading /scratch/picasa/July 2013 5968222817558851361/1.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/10.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/11.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/12.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/13.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/14.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/15.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/16.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/17.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/18.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/19.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/2.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/20.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/21.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/22.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/23.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/24.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/25.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/26.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/3.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/4.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/5.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/6.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/7.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/8.jpeg
# Uploading /scratch/picasa/July 2013 5968222817558851361/9.jpeg
# Creating album January 2013 5834660236380634641
# Uploading /scratch/picasa/January 2013 5834660236380634641/1.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/10.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/11.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/12.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/13.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/14.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/15.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/16.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/17.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/18.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/19.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/2.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/20.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/21.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/22.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/23.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/24.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/25.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/26.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/27.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/28.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/29.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/3.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/30.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/31.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/32.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/33.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/34.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/35.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/36.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/37.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/38.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/39.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/4.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/40.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/41.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/42.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/43.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/5.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/6.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/7.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/8.jpeg
# Uploading /scratch/picasa/January 2013 5834660236380634641/9.jpeg
# Creating album Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/1.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/10.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/11.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/12.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/13.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/14.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/15.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/16.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/17.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/18.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/19.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/2.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/20.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/21.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/22.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/23.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/24.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/25.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/26.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/27.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/28.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/29.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/3.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/30.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/31.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/32.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/33.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/34.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/35.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/36.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/37.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/38.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/39.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/4.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/40.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/41.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/42.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/43.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/44.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/45.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/46.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/47.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/48.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/49.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/5.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/50.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/51.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/52.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/53.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/54.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/55.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/56.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/6.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/7.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/8.jpeg
# Uploading /scratch/picasa/Week 12, Δωδέκατη Εβδομάδα, Двенадцатая неделя 5694898495609166001/9.jpeg
# Creating album September 2012 5865060362827508257
# Uploading /scratch/picasa/September 2012 5865060362827508257/1.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/10.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/100.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/101.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/102.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/103.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/104.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/105.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/106.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/107.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/108.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/109.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/11.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/110.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/111.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/112.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/113.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/114.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/115.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/116.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/117.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/118.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/119.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/12.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/120.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/121.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/122.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/123.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/124.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/125.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/126.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/127.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/128.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/129.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/13.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/130.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/131.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/132.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/133.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/134.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/135.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/14.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/15.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/16.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/17.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/18.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/19.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/2.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/22.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/23.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/24.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/25.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/26.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/27.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/3.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/30.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/31.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/32.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/33.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/35.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/36.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/37.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/38.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/39.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/4.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/40.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/41.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/42.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/43.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/44.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/45.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/46.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/47.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/48.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/49.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/5.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/50.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/51.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/52.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/53.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/54.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/55.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/56.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/57.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/58.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/59.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/6.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/60.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/61.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/62.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/63.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/64.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/65.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/66.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/67.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/68.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/69.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/7.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/70.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/71.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/72.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/73.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/74.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/75.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/76.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/77.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/78.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/79.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/8.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/80.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/81.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/82.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/83.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/84.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/85.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/86.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/87.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/88.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/89.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/9.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/90.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/91.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/92.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/93.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/94.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/95.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/96.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/97.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/98.jpeg
# Uploading /scratch/picasa/September 2012 5865060362827508257/99.jpeg
# Creating album December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/1.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/10.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/11.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/12.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/13.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/14.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/15.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/16.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/17.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/18.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/19.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/2.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/20.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/21.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/22.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/23.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/24.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/25.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/26.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/27.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/28.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/29.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/3.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/30.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/31.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/32.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/33.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/34.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/35.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/36.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/4.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/5.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/6.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/7.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/8.jpeg
# Uploading /scratch/picasa/December 2013 (Lego Museum and MTA Transit Museum) 5957739391004980113/9.jpeg
# Creating album Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/1.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/10.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/11.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/12.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/13.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/14.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/15.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/16.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/17.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/18.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/19.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/2.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/20.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/21.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/22.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/23.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/3.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/4.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/5.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/6.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/7.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/8.jpeg
# Uploading /scratch/picasa/Day 7, Έβδομη μέρα, Седьмой день 5616981450277819457/9.jpeg
# Creating album Day 6, Έκτη μέρα, Шестой день 5615898230949925601
# Uploading /scratch/picasa/Day 6, Έκτη μέρα, Шестой день 5615898230949925601/1.jpeg
# Uploading /scratch/picasa/Day 6, Έκτη μέρα, Шестой день 5615898230949925601/10.jpeg
# Uploading /scratch/picasa/Day 6, Έκτη μέρα, Шестой день 5615898230949925601/11.jpeg
# Uploading /scratch/picasa/Day 6, Έκτη μέρα, Шестой день 5615898230949925601/12.jpeg
# Uploading /scratch/picasa/Day 6, Έκτη μέρα, Шестой день 5615898230949925601/13.jpeg
# Uploading /scratch/picasa/Day 6, Έκτη μέρα, Шестой день 5615898230949925601/14.jpeg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-287e76055762> in <module>()
#       4 albumDiff = compareLocalToWeb(localAlbums, webAlbums)
#       5 syncDirs(gd_client, albumDiff['both'], localAlbums, webAlbums)
# ----> 6 uploadDirs(gd_client, albumDiff['localOnly'], localAlbums)
#
# <ipython-input-12-ed8d168ff49c> in uploadDirs(gd_client, dirs, local)
#     330 def uploadDirs(gd_client, dirs, local):
#     331     for dir in dirs:
# --> 332         uploadDir(gd_client, dir, local[dir])
#     333
#     334 def uploadDir(gd_client, dir, localAlbum):
#
# <ipython-input-12-ed8d168ff49c> in uploadDir(gd_client, dir, localAlbum)
#     336     for f in localAlbum['files']:
#     337         localPath = os.path.join(localAlbum['path'], f)
# --> 338         upload(gd_client, localPath, webAlbum, f)
#     339
#     340 # Global used for a temp directory
#
# <ipython-input-12-ed8d168ff49c> in upload(gd_client, localPath, album, fileName)
#     372         try:
#     373             if isImage:
# --> 374                 gd_client.InsertPhoto(album, picasa_photo, localPath, content_type=contentType)
#     375             else:
#     376                 gd_client.InsertVideo(album, picasa_photo, localPath, content_type=contentType)
#
# /usr/local/lib/python2.7/dist-packages/gdata/photos/service.pyc in InsertPhoto(self, album_or_uri, photo, filename_or_handle, content_type)
#     424     try:
#     425       return self.Post(photo, uri=feed_uri, media_source=mediasource,
# --> 426         converter=gdata.photos.PhotoEntryFromString)
#     427     except gdata.service.RequestError, e:
#     428       raise GooglePhotosException(e.args[0])
#
# /usr/local/lib/python2.7/dist-packages/gdata/service.pyc in Post(self, data, uri, extra_headers, url_params, escape_params, redirects_remaining, media_source, converter)
#    1234         extra_headers=extra_headers, url_params=url_params,
#    1235         escape_params=escape_params, redirects_remaining=redirects_remaining,
# -> 1236         media_source=media_source, converter=converter)
#    1237
#    1238   def PostOrPut(self, verb, data, uri, extra_headers=None, url_params=None,
#
# /usr/local/lib/python2.7/dist-packages/gdata/service.pyc in PostOrPut(self, verb, data, uri, extra_headers, url_params, escape_params, redirects_remaining, media_source, converter)
#    1301       server_response = self.request(verb, uri,
#    1302           data=[multipart[0], data_str, multipart[1], media_source.file_handle,
# -> 1303               multipart[2]], headers=extra_headers, url_params=url_params)
#    1304       result_body = server_response.read()
#    1305
#
# /usr/local/lib/python2.7/dist-packages/atom/__init__.pyc in optional_warn_function(*args, **kwargs)
#      91       if ENABLE_V1_WARNINGS:
#      92         warnings.warn(warning, DeprecationWarning, stacklevel=2)
# ---> 93       return f(*args, **kwargs)
#      94     # Preserve the original name to avoid masking all decorated functions as
#      95     # 'deprecated_function'
#
# /usr/local/lib/python2.7/dist-packages/atom/service.pyc in request(self, operation, url, data, headers, url_params)
#     184       auth_token = self.token_store.find_token(url)
#     185     return auth_token.perform_request(self.http_client, operation, url,
# --> 186         data=data, headers=all_headers)
#     187
#     188   request = atom.v1_deprecated(
#
# /usr/local/lib/python2.7/dist-packages/atom/http_interface.pyc in perform_request(self, http_client, operation, url, data, headers)
#     146                       headers=None):
#     147     """For the GenericToken, no Authorization token is set."""
# --> 148     return http_client.request(operation, url, data=data, headers=headers)
#     149
#     150   def valid_for_scope(self, url):
#
# /usr/local/lib/python2.7/dist-packages/atom/http.pyc in request(self, operation, url, data, headers)
#     172
#     173     # Return the HTTP Response from the server.
# --> 174     return connection.getresponse()
#     175
#     176   def _prepare_connection(self, url, headers):
#
# /usr/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1043         response = self.response_class(*args, **kwds)
#    1044
# -> 1045         response.begin()
#    1046         assert response.will_close != _UNKNOWN
#    1047         self.__state = _CS_IDLE
#
# /usr/lib/python2.7/httplib.pyc in begin(self)
#     407         # read until we get a non-100 response
#     408         while True:
# --> 409             version, status, reason = self._read_status()
#     410             if status != CONTINUE:
#     411                 break
#
# /usr/lib/python2.7/httplib.pyc in _read_status(self)
#     363     def _read_status(self):
#     364         # Initialize with Simple-Response defaults
# --> 365         line = self.fp.readline(_MAXLINE + 1)
#     366         if len(line) > _MAXLINE:
#     367             raise LineTooLong("header line")
#
# /usr/lib/python2.7/socket.pyc in readline(self, size)
#     474             while True:
#     475                 try:
# --> 476                     data = self._sock.recv(self._rbufsize)
#     477                 except error, e:
#     478                     if e.args[0] == EINTR:
#
# /usr/lib/python2.7/ssl.pyc in recv(self, buflen, flags)
#     339                     "non-zero flags not allowed in calls to recv() on %s" %
#     340                     self.__class__)
# --> 341             return self.read(buflen)
#     342         else:
#     343             return self._sock.recv(buflen, flags)
#
# /usr/lib/python2.7/ssl.pyc in read(self, len)
#     258
#     259         try:
# --> 260             return self._sslobj.read(len)
#     261         except SSLError, x:
#     262             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
